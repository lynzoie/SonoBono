# %%
import os
from matplotlib import pyplot as plt

path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)
# %matplotlib inline

import numpy as np

from echo_lib.echo_transform_utils import *

# %% [markdown]
# Get the reference echo of pole at 1 meter distance, 0 degree, raw

# %%
pole1m_raw = get_raw_echo(1, 1.0, 0.0, random_mode = False, index=0)

# %%
# %matplotlib notebook

# %%
plt.rcParams.update({'font.size': 26})
#plt.rcParams.update({'font.weight': 'normal'})
fig, ax = plt.subplots(figsize = (6,5))
ax.plot(d_axis, pole1m_raw['left'], linewidth = 0.5, alpha=0.5)
ax.plot(d_axis, pole1m_raw['right'], linewidth = 0.5, alpha=0.5)
ax.set_xlim(0,3.5)
ax.set_ylim(-1000,1000)
ax.legend(['left', 'right'])
ax.set_xlabel('Distance (meter)')
ax.set_ylabel('Raw waveform (a.u.)')
ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
plant1m_raw = get_raw_echo(2, 1.0, 0.0, random_mode = False, index=0)

# %%
plt.rcParams.update({'font.size': 26})
#plt.rcParams.update({'font.weight': 'normal'})
fig, ax = plt.subplots(figsize = (6,5))
ax.plot(d_axis, plant1m_raw['left'], linewidth = 0.5, alpha=0.5)
ax.plot(d_axis, plant1m_raw['right'], linewidth = 0.5, alpha=0.5)
ax.set_xlim(0,3.5)
ax.set_ylim(-1000,1000)
ax.legend(['left', 'right'])
ax.set_xlabel('Distance (meter)')
ax.set_ylabel('Raw waveform (a.u.)')
ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
pole1m_envelope = echo2envelope(pole1m_raw)

# %%
fig, ax = plt.subplots(figsize = (6,5))
ax.plot(d_axis, pole1m_envelope['left'], linewidth = 2, alpha=0.8)
ax.plot(d_axis, pole1m_envelope['right'], linewidth = 2, alpha=0.8)
ax.set_xlim(0,3.499)
ax.set_ylim(0,6)
ax.legend(['left', 'right'])
ax.set_xlabel('Distance (meter)')
ax.set_ylabel('Envelope (a.u.)')
ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
plant1m_envelope = echo2envelope(plant1m_raw)

# %%
fig, ax = plt.subplots(figsize = (6,5))
ax.plot(d_axis, plant1m_envelope['left'], linewidth = 2, alpha=0.8)
ax.plot(d_axis, plant1m_envelope['right'], linewidth = 2, alpha=0.8)
ax.set_xlim(0,3.499)
ax.set_ylim(0,6)
ax.legend(['left', 'right'])
ax.set_xlabel('Distance (meter)')
ax.set_ylabel('Envelope (a.u.)')
ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
pole1m_z = echo2envelope_z(pole1m_raw)
plant1m_z = echo2envelope_z(plant1m_raw)

# %%
fig, ax = plt.subplots(figsize = (6,5))

ax.bar(range(50), pole1m_z['left'][:50], alpha=0.6, label='left')                               
ax.bar(range(50), pole1m_z['right'][:50], alpha=0.6, label='right')                              
ax.legend()                                                                               
dist_z = np.floor(100*np.linspace(0.04,3.51,50))/100                                       
ax.set_xticks(np.arange(len(dist_z))[::9])                                                
ax.set_xticklabels(np.round(dist_z,2)[::9])                                               
#ax2.set_title('Compressed envelope of current time step')                                  
ax.set_xlabel('Distance (meter)')                                                         
ax.set_xlim(-0.5,49.5)
ax.set_ylabel('Compressed envelope (a.u)')
#ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
fig, ax = plt.subplots(figsize = (6,5))

ax.bar(range(50), plant1m_z['left'][:50], alpha=0.6, label='left')                               
ax.bar(range(50), plant1m_z['right'][:50], alpha=0.6, label='right')                              
ax.legend()                                                                               
dist_z = np.floor(100*np.linspace(0.04,3.51,50))/100                                       
ax.set_xticks(np.arange(len(dist_z))[::9])                                                
ax.set_xticklabels(np.round(dist_z,2)[::9])                                               
#ax2.set_title('Compressed envelope of current time step')                                  
ax.set_xlabel('Distance (meter)')                                                         
ax.set_xlim(-0.5,49.5)
ax.set_ylabel('Compressed envelope (a.u)')
#ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
pole1m_quiet = quiet_envelope(pole1m_z)
plant1m_quiet = quiet_envelope(plant1m_z)

# %%
fig, ax = plt.subplots(figsize = (6,5))

ax.bar(range(50), pole1m_quiet['left'][:50]/5.73, alpha=0.6, label='left')                               
ax.bar(range(50), pole1m_quiet['right'][:50]/5.73, alpha=0.6, label='right')                              
ax.legend()                                                                               
dist_z = np.floor(100*np.linspace(0.04,3.51,50))/100                                       
ax.set_xticks(np.arange(len(dist_z))[::9])                                                
ax.set_xticklabels(np.round(dist_z,2)[::9])                                               
#ax2.set_title('Compressed envelope of current time step')                                  
ax.set_xlabel('Distance (meter)')                                                         
ax.set_xlim(0,49)
ax.set_ylim(0,1)
ax.set_ylabel('Normalized (a.u)')
#ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">

# %%
fig, ax = plt.subplots(figsize = (6,5))

ax.bar(range(50), plant1m_quiet['left'][:50]/5.73, alpha=0.6, label='left')                               
ax.bar(range(50), plant1m_quiet['right'][:50]/5.73, alpha=0.6, label='right')                              
ax.legend()                                                                               
dist_z = np.floor(100*np.linspace(0.04,3.51,50))/100                                       
ax.set_xticks(np.arange(len(dist_z))[::9])                                                
ax.set_xticklabels(np.round(dist_z,2)[::9])                                               
#ax2.set_title('Compressed envelope of current time step')                                  
ax.set_xlabel('Distance (meter)')                                                         
ax.set_xlim(0,49)
ax.set_ylim(0,1)
ax.set_ylabel('Normalized (a.u)')
#ax.ticklabel_format(axis='y',style='sci', scilimits=(0,1))
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="777.777798381853">
